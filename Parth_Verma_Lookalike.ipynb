# %%
! pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /home/parth/Desktop/Python/geneza-task/.venv/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/parth/Desktop/Python/geneza-task/.venv/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/parth/Desktop/Python/geneza-task/.venv/lib/python3.10/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/parth/Desktop/Python/geneza-task/.venv/lib/python3.10/site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/parth/Desktop/Python/geneza-task/.venv/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip available: 22.2.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MultiLabelBinarizer,  LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity

# %%
customers_df = pd.read_csv('dataset/Customers.csv')
products_df = pd.read_csv('dataset/Products.csv')
transactions_df = pd.read_csv('dataset/Transactions.csv')

# %%
customers_df.head()
# Out:
#   CustomerID        CustomerName         Region  SignupDate
# 0      C0001    Lawrence Carroll  South America  2022-07-10
# 1      C0002      Elizabeth Lutz           Asia  2022-02-13
# 2      C0003      Michael Rivera  South America  2024-03-07
# 3      C0004  Kathleen Rodriguez  South America  2022-10-09
# 4      C0005         Laura Weber           Asia  2022-08-15

# %%
transactions_df.head()
# Out:
#   TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0        T00001      C0199      P067  2024-08-25 12:38:23         1
# 1        T00112      C0146      P067  2024-05-27 22:23:54         1
# 2        T00166      C0127      P067  2024-04-25 07:38:55         1
# 3        T00272      C0087      P067  2024-03-26 22:55:37         2
# 4        T00363      C0070      P067  2024-03-21 15:10:10         3
#
#    TotalValue   Price
# 0      300.68  300.68
# 1      300.68  300.68
# 2      300.68  300.68
# 3      601.36  300.68
# 4      902.04  300.68

# %%
products_df.head()
# Out:
#   ProductID              ProductName     Category   Price
# 0      P001     ActiveWear Biography        Books  169.30
# 1      P002    ActiveWear Smartwatch  Electronics  346.30
# 2      P003  ComfortLiving Biography        Books   44.12
# 3      P004            BookWorld Rug   Home Decor   95.69
# 4      P005          TechPro T-Shirt     Clothing  429.31

# %%
df = pd.merge(transactions_df, customers_df[['CustomerID', 'Region']], on='CustomerID', how='inner')
df = pd.merge(df, products_df[['ProductID', 'ProductName', 'Category']], on='ProductID', how='inner')
df
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price         Region                      ProductName  \
# 0        300.68  300.68         Europe  ComfortLiving Bluetooth Speaker
# 1        300.68  300.68           Asia  ComfortLiving Bluetooth Speaker
# 2        300.68  300.68         Europe  ComfortLiving Bluetooth Speaker
# 3        601.36  300.68  South America  ComfortLiving Bluetooth Speaker
# 4        902.04  300.68         Europe  ComfortLiving Bluetooth Speaker
# ..          ...     ...            ...                              ...
# 995      459.86  459.86  South America             SoundWave Smartwatch
# 996     1379.58  459.86  North America             SoundWave Smartwatch
# 997     1839.44  459.86  North America             SoundWave Smartwatch
# 998      919.72  459.86           Asia             SoundWave Smartwatch
# 999      459.86  459.86  North America             SoundWave Smartwatch
#
#         Category
# 0    Electronics
# 1    Electronics
# 2    Electronics
# 3    Electronics
# 4    Electronics
# ..           ...
# 995  Electronics
# 996  Electronics
# 997  Electronics
# 998  Electronics
# 999  Electronics
#
# [1000 rows x 10 columns]

# %%
df[df['CustomerID']=='C0199']
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 439        T00761      C0199      P022  2024-10-01 05:57:09         4
# 918        T00626      C0199      P079  2024-08-17 12:06:08         2
# 940        T00963      C0199      P008  2024-10-26 00:01:58         2
#
#      TotalValue   Price  Region                      ProductName     Category
# 0        300.68  300.68  Europe  ComfortLiving Bluetooth Speaker  Electronics
# 439      550.16  137.54  Europe               HomeSense Wall Art   Home Decor
# 918      834.74  417.37  Europe                   ActiveWear Rug   Home Decor
# 940      293.70  146.85  Europe      BookWorld Bluetooth Speaker  Electronics

# %%
df[df['CustomerID']=='C0001']
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 135        T00015      C0001      P054  2024-01-19 03:12:55         2
# 442        T00932      C0001      P022  2024-09-17 09:01:18         3
# 546        T00085      C0001      P096  2024-04-08 00:01:00         2
# 724        T00445      C0001      P083  2024-05-07 03:11:44         2
# 776        T00436      C0001      P029  2024-11-02 17:04:16         3
#
#      TotalValue   Price         Region            ProductName     Category
# 135      114.60   57.30  South America     SoundWave Cookbook        Books
# 442      412.62  137.54  South America     HomeSense Wall Art   Home Decor
# 546      614.94  307.47  South America   SoundWave Headphones  Electronics
# 724      911.44  455.72  South America  ActiveWear Smartwatch  Electronics
# 776     1300.92  433.64  South America     TechPro Headphones  Electronics

# %%
def safe_mode(series):
    mode = series.mode()
    return mode.tolist() if len(mode) > 0 else []

# %%
df = df.groupby('CustomerID').agg({
    'TotalValue': 'sum',
    'TransactionID': 'count',
    'ProductID': pd.Series.nunique,
    'Category': safe_mode,
    'Region': lambda x: x.unique()[0]
}).reset_index()
df.head()
# Out:
#   CustomerID  TotalValue  TransactionID  ProductID                Category  \
# 0      C0001     3354.52              5          5           [Electronics]
# 1      C0002     1862.74              4          4  [Clothing, Home Decor]
# 2      C0003     2725.38              4          4            [Home Decor]
# 3      C0004     5354.88              8          8     [Books, Home Decor]
# 4      C0005     2034.24              3          3           [Electronics]
#
#           Region
# 0  South America
# 1           Asia
# 2  South America
# 3  South America
# 4           Asia

# %%
df.rename(columns={
    'TotalValue': 'TotalSpend',
    'TransactionID': 'NumTransactions',
    'ProductID': 'NumUniqueProducts',
}, inplace=True)
df.head()
# Out:
#   CustomerID  TotalSpend  NumTransactions  NumUniqueProducts  \
# 0      C0001     3354.52                5                  5
# 1      C0002     1862.74                4                  4
# 2      C0003     2725.38                4                  4
# 3      C0004     5354.88                8                  8
# 4      C0005     2034.24                3                  3
#
#                  Category         Region
# 0           [Electronics]  South America
# 1  [Clothing, Home Decor]           Asia
# 2            [Home Decor]  South America
# 3     [Books, Home Decor]  South America
# 4           [Electronics]           Asia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         199 non-null    object
#  1   TotalSpend         199 non-null    float64
#  2   NumTransactions    199 non-null    int64
#  3   NumUniqueProducts  199 non-null    int64
#  4   Category           199 non-null    object
#  5   Region             199 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.5+ KB

# %%
label_encoder = LabelEncoder()
df['Region'] = label_encoder.fit_transform(df['Region'])

# %%
df.head()
# Out:
#   CustomerID  TotalSpend  NumTransactions  NumUniqueProducts  \
# 0      C0001     3354.52                5                  5
# 1      C0002     1862.74                4                  4
# 2      C0003     2725.38                4                  4
# 3      C0004     5354.88                8                  8
# 4      C0005     2034.24                3                  3
#
#                  Category  Region
# 0           [Electronics]       3
# 1  [Clothing, Home Decor]       0
# 2            [Home Decor]       3
# 3     [Books, Home Decor]       3
# 4           [Electronics]       0

# %%
mlb = MultiLabelBinarizer()
category_encoded = mlb.fit_transform(df['Category'])
category_labels = mlb.classes_
category_labels
# Out:
# array(['Books', 'Clothing', 'Electronics', 'Home Decor'], dtype=object)

# %%
category_df = pd.DataFrame(category_encoded, columns=category_labels, index=df.index)
df = pd.concat([df.drop('Category', axis=1), category_df], axis=1)
df.head()
# Out:
#   CustomerID  TotalSpend  NumTransactions  NumUniqueProducts  Region  Books  \
# 0      C0001     3354.52                5                  5       3      0
# 1      C0002     1862.74                4                  4       0      0
# 2      C0003     2725.38                4                  4       3      0
# 3      C0004     5354.88                8                  8       3      1
# 4      C0005     2034.24                3                  3       0      0
#
#    Clothing  Electronics  Home Decor
# 0         0            1           0
# 1         1            0           1
# 2         0            0           1
# 3         0            0           1
# 4         0            1           0

# %%
scaler = StandardScaler()
numerical_features = ['TotalSpend', 'NumTransactions', 'NumUniqueProducts']
df[numerical_features] = scaler.fit_transform(df[numerical_features])
df.head()
# Out:
#   CustomerID  TotalSpend  NumTransactions  NumUniqueProducts  Region  Books  \
# 0      C0001   -0.061701        -0.011458           0.050047       3      0
# 1      C0002   -0.877744        -0.467494          -0.424204       0      0
# 2      C0003   -0.405857        -0.467494          -0.424204       3      0
# 3      C0004    1.032547         1.356650           1.472798       3      1
# 4      C0005   -0.783929        -0.923530          -0.898455       0      0
#
#    Clothing  Electronics  Home Decor
# 0         0            1           0
# 1         1            0           1
# 2         0            0           1
# 3         0            0           1
# 4         0            1           0

# %%
feature_matrix = df.drop(['CustomerID'], axis=1)
feature_matrix.head()
# Out:
#    TotalSpend  NumTransactions  NumUniqueProducts  Region  Books  Clothing  \
# 0   -0.061701        -0.011458           0.050047       3      0         0
# 1   -0.877744        -0.467494          -0.424204       0      0         1
# 2   -0.405857        -0.467494          -0.424204       3      0         0
# 3    1.032547         1.356650           1.472798       3      1         0
# 4   -0.783929        -0.923530          -0.898455       0      0         0
#
#    Electronics  Home Decor
# 0            1           0
# 1            0           1
# 2            0           1
# 3            0           1
# 4            1           0

# %%
similarity_matrix = cosine_similarity(feature_matrix)

# %%
input_customer_id = 'C0001' 
customer_idx = df[df['CustomerID'] == input_customer_id].index[0]
similarities = similarity_matrix[customer_idx]
sorted_indices = similarities.argsort()[::-1][1:4]
similar_customer_ids = df.iloc[sorted_indices]['CustomerID'].tolist()
similarity_scores = similarities[sorted_indices].tolist()

for customer_id, score in zip(similar_customer_ids, similarity_scores):
    print(f"Customer ID: {customer_id}, Similarity Score: {score:.3f}")
# Out:
# Customer ID: C0190, Similarity Score: 0.998
# Customer ID: C0048, Similarity Score: 0.996
# Customer ID: C0091, Similarity Score: 0.989

# %%
lookalike_data = []

for customer_id in df['CustomerID'][:20]:
    customer_idx = df[df['CustomerID'] == customer_id].index[0]
    similarities = similarity_matrix[customer_idx]
    sorted_indices = similarities.argsort()[::-1][1:4] 
    similar_customer_ids = df.iloc[sorted_indices]['CustomerID'].tolist()
    similarity_scores = similarities[sorted_indices].tolist()
    similar_customers_dict = {similar_customer_ids[i]: round(similarity_scores[i], 3) for i in range(len(similar_customer_ids))}
    lookalike_data.append([customer_id, str(similar_customers_dict)])

# %%
lookalike_data[:2]
# Out:
# [['C0001', "{'C0190': 0.998, 'C0048': 0.996, 'C0091': 0.989}"],
#  ['C0002', "{'C0043': 0.881, 'C0106': 0.87, 'C0178': 0.79}"]]

# %%
formatted_data = {}

for customer_id, similar_customers_str in lookalike_data:
    similar_customers_dict = eval(similar_customers_str)
    formatted_data[customer_id] = [{"cust_id": k, "score": v} for k, v in similar_customers_dict.items()]

# %%
formatted_data
# Out:
# {'C0001': [{'cust_id': 'C0190', 'score': 0.998},
#   {'cust_id': 'C0048', 'score': 0.996},
#   {'cust_id': 'C0091', 'score': 0.989}],
#  'C0002': [{'cust_id': 'C0043', 'score': 0.881},
#   {'cust_id': 'C0106', 'score': 0.87},
#   {'cust_id': 'C0178', 'score': 0.79}],
#  'C0003': [{'cust_id': 'C0031', 'score': 0.993},
#   {'cust_id': 'C0052', 'score': 0.99},
#   {'cust_id': 'C0158', 'score': 0.986}],
#  'C0004': [{'cust_id': 'C0113', 'score': 0.959},
#   {'cust_id': 'C0104', 'score': 0.956},
#   {'cust_id': 'C0122', 'score': 0.935}],
#  'C0005': [{'cust_id': 'C0186', 'score': 0.997},
#   {'cust_id': 'C0007', 'score': 0.987},
#   {'cust_id': 'C0146', 'score': 0.948}],
#  'C0006': [{'cust_id': 'C0011', 'score': 0.976},
#   {'cust_id': 'C0171', 'score': 0.968},
#   {'cust_id': 'C0137', 'score': 0.968}],
#  'C0007': [{'cust_id': 'C0005', 'score': 0.987},
#   {'cust_id': 'C0115', 'score': 0.984},
#   {'cust_id': 'C0186', 'score': 0.974}],
#  'C0008': [{'cust_id': 'C0124', 'score': 0.951},
#   {'cust_id': 'C0109', 'score': 0.93},
#   {'cust_id': 'C0065', 'score': 0.917}],
#  'C0009': [{'cust_id': 'C0033', 'score': 0.966},
#   {'cust_id': 'C0062', 'score': 0.966},
#   {'cust_id': 'C0061', 'score': 0.964}],
#  'C0010': [{'cust_id': 'C0009', 'score': 0.962},
#   {'cust_id': 'C0061', 'score': 0.942},
#   {'cust_id': 'C0029', 'score': 0.941}],
#  'C0011': [{'cust_id': 'C0137', 'score': 0.998},
#   {'cust_id': 'C0191', 'score': 0.992},
#   {'cust_id': 'C0174', 'score': 0.99}],
#  'C0012': [{'cust_id': 'C0113', 'score': 0.982},
#   {'cust_id': 'C0163', 'score': 0.978},
#   {'cust_id': 'C0195', 'score': 0.974}],
#  'C0013': [{'cust_id': 'C0102', 'score': 0.959},
#   {'cust_id': 'C0067', 'score': 0.954},
#   {'cust_id': 'C0099', 'score': 0.953}],
#  'C0014': [{'cust_id': 'C0060', 'score': 0.999},
#   {'cust_id': 'C0097', 'score': 0.956},
#   {'cust_id': 'C0110', 'score': 0.952}],
#  'C0015': [{'cust_id': 'C0151', 'score': 0.95},
#   {'cust_id': 'C0131', 'score': 0.936},
#   {'cust_id': 'C0073', 'score': 0.931}],
#  'C0016': [{'cust_id': 'C0183', 'score': 1.0},
#   {'cust_id': 'C0107', 'score': 0.983},
#   {'cust_id': 'C0067', 'score': 0.966}],
#  'C0017': [{'cust_id': 'C0075', 'score': 0.942},
#   {'cust_id': 'C0156', 'score': 0.94},
#   {'cust_id': 'C0139', 'score': 0.927}],
#  'C0018': [{'cust_id': 'C0168', 'score': 0.967},
#   {'cust_id': 'C0118', 'score': 0.926},
#   {'cust_id': 'C0155', 'score': 0.923}],
#  'C0019': [{'cust_id': 'C0047', 'score': 0.857},
#   {'cust_id': 'C0116', 'score': 0.845},
#   {'cust_id': 'C0147', 'score': 0.845}],
#  'C0020': [{'cust_id': 'C0130', 'score': 0.983},
#   {'cust_id': 'C0197', 'score': 0.972},
#   {'cust_id': 'C0058', 'score': 0.927}]}

# %%
lookalike_df = pd.DataFrame()
lookalikes = []
for key, val in formatted_data.items():
    item = key + ":" + str(val)
    lookalikes.append(item)
lookalike_df['Lookalikes'] = lookalikes
lookalike_df.head()
# Out:
#                                           Lookalikes
# 0  C0001:[{'cust_id': 'C0190', 'score': 0.998}, {...
# 1  C0002:[{'cust_id': 'C0043', 'score': 0.881}, {...
# 2  C0003:[{'cust_id': 'C0031', 'score': 0.993}, {...
# 3  C0004:[{'cust_id': 'C0113', 'score': 0.959}, {...
# 4  C0005:[{'cust_id': 'C0186', 'score': 0.997}, {...

# %%
lookalike_df.to_csv('Lookalikes.csv', index=False)

# %%
lookalike_df.head()
# Out:
#                                           Lookalikes
# 0  C0001:[{'cust_id': 'C0190', 'score': 0.998}, {...
# 1  C0002:[{'cust_id': 'C0043', 'score': 0.881}, {...
# 2  C0003:[{'cust_id': 'C0031', 'score': 0.993}, {...
# 3  C0004:[{'cust_id': 'C0113', 'score': 0.959}, {...
# 4  C0005:[{'cust_id': 'C0186', 'score': 0.997}, {...
